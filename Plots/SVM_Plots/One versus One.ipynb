# %%
 #pip install shapely
 
 
import matplotlib.pyplot as plt
import numpy as np
from shapely.geometry import Point, Polygon

"""plt.rcParams.update({
     "text.usetex": True,
     "font.family": "cmr"
 })"""
# Out:
# 'plt.rcParams.update({\n    "text.usetex": True,\n    "font.family": "cmr"\n})'

# %%
#Plots the lines 
x = np.arange(-10, 30, 0.01, dtype=np.float64)
y1=48-0.1*x
y2=93-7*x
y3=-0.731+2*x

plt.plot(x, y1, 'C0',label='A VS B')
plt.plot(x, y2, 'C1',label='B VS C')
plt.plot(x, y3, 'C2',label='A VS C')


#Plot the point that is which to determine the class for 
px=2.5
py=60

plt.plot(px, py, 'C3.', markersize=30,label='Text point')







#Arrows 


"""""
a3 = patches.FancyArrowPatch((13, -16), (17.5, -12), arrowstyle='<->', mutation_scale=10)
plt.gca().add_patch(a3)

a4 = patches.FancyArrowPatch((0, -8), (0, 6.5), arrowstyle='<->', mutation_scale=10)
plt.gca().add_patch(a4)

a5 = patches.FancyArrowPatch((0, 40), (0, 56), arrowstyle='<->', mutation_scale=10)
plt.gca().add_patch(a5)
"""""


#Text plots: 

front=35
plt.text(20, 0, 'C', fontsize = front)

plt.text(0, 20, 'B', fontsize = front)

plt.text(10, 65, 'A', fontsize = front)

plt.text(12, 32.5, '?', fontsize = front)

#Something abouting plotting
plt.axis('off')
#plt.grid('on')
plt.xlim([-5,30])
plt.ylim([-20,80])
plt.legend(loc='upper right')
plt.savefig("one_against_one_example.pdf", format="pdf", bbox_inches="tight")
#plt.axis('equal')
