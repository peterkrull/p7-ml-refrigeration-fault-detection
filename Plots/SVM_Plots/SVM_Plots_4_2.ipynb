# %%
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams.update({
     "text.usetex": True,
     "font.family": "cmr"
 })

# %%
x = np.arange(0, 1000, 0.1, dtype=np.double)
y1=-x
y2=-x+200
y3=-x+400
plt.plot(x, y1, 'k', label='line 0')
plt.plot(x, y2, 'k--', label='line 1')
plt.plot(x, y3, 'k', label='line 2')

px=200
plt.plot(px, -px, 'go', markersize=5)
plt.plot(px, -px+400, 'ro', markersize=5)
px=700
plt.plot(px, -px+400, 'ro', markersize=5)


i=0
x_p1=[]
y_p1=[]
while(i<100):
    y_p_1 = random.uniform(np.min(y3), np.max(y3))
    x_p_1 = random.uniform(np.min(x), np.max(x))
    if(y_p_1<-x_p_1-20):
        x_p1.append(x_p_1)
        y_p1.append(y_p_1)
        i=i+1


i=0
x_p2=[]
y_p2=[]
while(i<100):
    y_p_2 = random.uniform(np.min(y1), np.max(y1))
    x_p_2 = random.uniform(np.min(x), np.max(x))
    if(y_p_2>-x_p_2+420):
        x_p2.append(x_p_2)
        y_p2.append(y_p_2)
        i=i+1

plt.plot(x_p1, y_p1, 'go', label='line 3')
plt.plot(x_p2, y_p2, 'ro', label='line 4')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [22], line 20
#      18 y_p1=[]
#      19 while(i<100):
# ---> 20     y_p_1 = random.uniform(np.min(y3), np.max(y3))
#      21     x_p_1 = random.uniform(np.min(x), np.max(x))
#      22     if(y_p_1<-x_p_1-20):
#
# NameError: name 'random' is not defined

# %%
pip install shapely
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from shapely.geometry import Point, Polygon
def Random_Points_in_Polygon(polygon, number):
    points = []
    minx, miny, maxx, maxy = polygon.bounds
    while len(points) < number:
        pnt = Point(np.random.uniform(minx, maxx), np.random.uniform(miny, maxy))
        if polygon.contains(pnt):
            points.append(pnt)
    return points

x = np.arange(0, 1000, 0.1, dtype=np.double)
y1=-x
y2=-x+200
y3=-x+400
plt.plot(x, y1, 'k', label='line 0')
plt.plot(x, y2, 'k--', label='line 1')
plt.plot(x, y3, 'k', label='line 2')

px=200
plt.plot(px, -px, 'go', markersize=5)
plt.plot(px, -px+400, 'ro', markersize=5)
px=700
plt.plot(px, -px+400, 'ro', markersize=5)

# %%
polygon = Polygon([[min(x), max(y3)],[max(x), max(y3)],[max(x), min(y3)],[min(x), max(y3)]])
points = Random_Points_in_Polygon(polygon, 100)

xs = [point.x for point in points]
ys = [point.y for point in points]

plt.plot(xs, ys, 'ro', label='line 3')



polygon2 = Polygon([[min(x), max(y1)],[min(x), min(y1)],[max(x), min(y1)],[min(x), max(y1)]])
points2 = Random_Points_in_Polygon(polygon2, 100)
xs2 = [point2.x for point2 in points2]
ys2 = [point2.y for point2 in points2]

plt.plot(xs2, ys2, 'go', label='line 4')

# %%
from shapely.geometry import Point, Polygon
def Random_Points_in_Polygon(polygon, number):
    points = []
    minx, miny, maxx, maxy = polygon.bounds
    while len(points) < number:
        pnt = Point(np.random.uniform(minx, maxx), np.random.uniform(miny, maxy))
        if polygon.contains(pnt):
            points.append(pnt)
    return points

x = np.arange(0, 1000, 0.1, dtype=np.double)
y1=-x
y2=-x+200
y3=-x+400
plt.plot(x, y1, 'k', label='line 0')
plt.plot(x, y2, 'k--', label='line 1')
plt.plot(x, y3, 'k', label='line 2')

px=200
plt.plot(px, -px, 'go', markersize=5)
plt.plot(px, -px+400, 'ro', markersize=5)
px=700
plt.plot(px, -px+400, 'ro', markersize=5)


polygon = Polygon([[min(x), max(y3)],[max(x), max(y3)],[max(x), min(y3)],[min(x), max(y3)]])
points = Random_Points_in_Polygon(polygon, 100)

xs = [point.x for point in points]
ys = [point.y for point in points]

plt.plot(xs, ys, 'ro', label='line 3')



polygon2 = Polygon([[min(x), max(y1)],[min(x), min(y1)],[max(x), min(y1)],[min(x), max(y1)]])
points2 = Random_Points_in_Polygon(polygon2, 100)
xs2 = [point2.x for point2 in points2]
ys2 = [point2.y for point2 in points2]

plt.plot(xs2, ys2, 'go', label='line 4')

# %%
from shapely.geometry import Point, Polygon
def Random_Points_in_Polygon(polygon, number):
    points = []
    minx, miny, maxx, maxy = polygon.bounds
    while len(points) < number:
        pnt = Point(np.random.uniform(minx, maxx), np.random.uniform(miny, maxy))
        if polygon.contains(pnt):
            points.append(pnt)
    return points

x = np.arange(0, 1000, 0.1, dtype=np.double)
y1=-x
y2=-x+200
y3=-x+400
plt.plot(x, y1, 'b', label='line 0')
plt.plot(x, y2, 'k--', label='line 1')
plt.plot(x, y3, 'b', label='line 2')

px=200
plt.plot(px, -px, 'go', markersize=5)
plt.plot(px, -px+400, 'ro', markersize=5)
px=700
plt.plot(px, -px+400, 'ro', markersize=5)


u=40
polygon = Polygon([[min(x+u), max(y3+u)],[max(x-u), max(y3+u)],[max(x-u), min(y3+u)],[min(x+u), max(y3+u)]])
points = Random_Points_in_Polygon(polygon, 100)

xs = [point.x for point in points]
ys = [point.y for point in points]

plt.plot(xs, ys, 'ro', label='line 3')



polygon2 = Polygon([[min(x+u), max(y1-u)],[min(x+u), min(y1-u)],[max(x-u), min(y1-u)],[min(x+u), max(y1-u)]])
points2 = Random_Points_in_Polygon(polygon2, 100)
xs2 = [point2.x for point2 in points2]
ys2 = [point2.y for point2 in points2]

plt.plot(xs2, ys2, 'go', label='line 4')
plt.text(120, 0, 'margin', fontsize = 10, bbox = dict(facecolor = 'gray', alpha = 0.9))
plt.text(600, 100, 'support vectors', fontsize = 10, bbox = dict(facecolor = 'gray', alpha = 0.9))
plt.text(680, -600, 'decision\nboundary', fontsize = 10, bbox = dict(facecolor = 'gray', alpha = 0.9))


pu=175
plt.arrow(pu, -pu+200, 60, 60, head_width = 40, width = 0.05, ec ='green')
plt.arrow(pu, -pu+200, -60, -60, head_width = 40, width = 0.05, ec ='green')

# %%
from shapely.geometry import Point, Polygon
def Random_Points_in_Polygon(polygon, number):
    points = []
    minx, miny, maxx, maxy = polygon.bounds
    while len(points) < number:
        pnt = Point(np.random.uniform(minx, maxx), np.random.uniform(miny, maxy))
        if polygon.contains(pnt):
            points.append(pnt)
    return points

x = np.arange(0, 1000, 0.1, dtype=np.double)
y1=-x
y2=-x+200
y3=-x+400
plt.plot(x, y1, 'b', label='line 0')
plt.plot(x, y2, 'k--', label='line 1')
plt.plot(x, y3, 'b', label='line 2')

px=200
plt.plot(px, -px, 'go', markersize=5)
plt.plot(px, -px+400, 'ro', markersize=5)
px=700
plt.plot(px, -px+400, 'ro', markersize=5)


u=40
polygon = Polygon([[min(x+u), max(y3+u)],[max(x-u), max(y3+u)],[max(x-u), min(y3+u)],[min(x+u), max(y3+u)]])
points = Random_Points_in_Polygon(polygon, 100)

xs = [point.x for point in points]
ys = [point.y for point in points]

plt.plot(xs, ys, 'ro', label='line 3')



polygon2 = Polygon([[min(x+u), max(y1-u)],[min(x+u), min(y1-u)],[max(x-u), min(y1-u)],[min(x+u), max(y1-u)]])
points2 = Random_Points_in_Polygon(polygon2, 100)
xs2 = [point2.x for point2 in points2]
ys2 = [point2.y for point2 in points2]

plt.plot(xs2, ys2, 'go', label='line 4')
plt.text(120, 0, 'margin', fontsize = 10, bbox = dict(facecolor = 'gray', alpha = 0.9))
plt.text(600, 100, 'support vectors', fontsize = 10, bbox = dict(facecolor = 'gray', alpha = 0.9))
plt.text(680, -600, 'decision\nboundary', fontsize = 10, bbox = dict(facecolor = 'gray', alpha = 0.9))


pu=175
plt.arrow(pu, -pu+200, 60, 60, head_width = 40, width = 0.05, ec ='green')
plt.arrow(pu, -pu+200, -60, -60, head_width = 40, width = 0.05, ec ='green')


hw=30
plt.arrow(700, 120, 200-700+hw, -200-120+hw, head_width = hw, width = 0.05, ec ='green')
plt.arrow(700, 120, 200-700+hw, 200-120+hw, head_width = hw, width = 0.05, ec ='green')
plt.arrow(700, 120, 700-700+hw, -300-120+hw, head_width = hw, width = 0.05, ec ='green')


plt.text(900, 300, '1', fontsize = 10, bbox = dict(facecolor = 'yellow', alpha = 0.9))
plt.text(100, -800, '-1', fontsize = 10, bbox = dict(facecolor = 'yellow', alpha = 0.9))

#200, -200
#200, 200
#700, -300
# Out:
# Text(100, -800, '-1')

# %%
from shapely.geometry import Point, Polygon
def Random_Points_in_Polygon(polygon, number):
    points = []
    minx, miny, maxx, maxy = polygon.bounds
    while len(points) < number:
        pnt = Point(np.random.uniform(minx, maxx), np.random.uniform(miny, maxy))
        if polygon.contains(pnt):
            points.append(pnt)
    return points

x = np.arange(0, 1000, 0.1, dtype=np.double)
y1=-x
y2=-x+200
y3=-x+400
plt.plot(x, y1, 'gray', label='line 0')
plt.plot(x, y2, 'k--', label='line 1')
plt.plot(x, y3, 'gray', label='line 2')

px=200
plt.plot(px, -px, 'C1.', markersize=5)
px=300
plt.plot(px, -px+400, 'C0.', markersize=5)
px=700
plt.plot(px, -px+400, 'C0.', markersize=5)


u=40
polygon = Polygon([[min(x+u), max(y3+u)],[max(x-u), max(y3+u)],[max(x-u), min(y3+u)],[min(x+u), max(y3+u)]])
points = Random_Points_in_Polygon(polygon, 70)

xs = [point.x for point in points]
ys = [point.y for point in points]

plt.plot(xs, ys, '.', label='line 3')



polygon2 = Polygon([[min(x+u), max(y1-u)],[min(x+u), min(y1-u)],[max(x-u), min(y1-u)],[min(x+u), max(y1-u)]])
points2 = Random_Points_in_Polygon(polygon2, 70)
xs2 = [point2.x for point2 in points2]
ys2 = [point2.y for point2 in points2]

plt.plot(xs2, ys2, '.', label='line 4')
plt.text(120, 0, 'margin', fontsize = 10, bbox = dict(facecolor = 'white', alpha = 0.9))
plt.text(600, 100, 'support vectors', fontsize = 10, bbox = dict(facecolor = 'white', alpha = 0.9))
plt.text(680, -600, 'decision\nboundary', fontsize = 10, bbox = dict(facecolor = 'white', alpha = 0.9))


pu=175
#plt.arrow(pu, -pu+200, 60, 60, head_width = 40, width = 0.05, ec ='green')
#plt.arrow(pu, -pu+200, -60, -60, head_width = 40, width = 0.05, ec ='green')




import matplotlib.patches as patches
style = "Simple, tail_width=0.5, head_width=4, head_length=8"
kw = dict(arrowstyle=style, color="k")
a1 = patches.FancyArrowPatch((pu, -pu+200), (120, -130), **kw)
plt.gca().add_patch(a1)
a2 = patches.FancyArrowPatch((pu, -pu+200), (220, 190), **kw)
plt.gca().add_patch(a2)


px=200
a3 = patches.FancyArrowPatch((700, 120), (px, -px), **kw)
plt.gca().add_patch(a3)
px=300
a4 = patches.FancyArrowPatch((700, 120), (px, -px+400), **kw)
plt.gca().add_patch(a4)
px=700
a5 = patches.FancyArrowPatch((700, 120), (px, -px+400), **kw)
plt.gca().add_patch(a5)

plt.text(900, 300, '1', fontsize = 10, bbox = dict(facecolor = 'white', alpha = 0.9))
plt.text(100, -800, '-1', fontsize = 10, bbox = dict(facecolor = 'white', alpha = 0.9))
plt.axis('off')
plt.savefig("SVM_Plots_4.2.pdf", format="pdf", bbox_inches="tight")

#200, -200
#200, 200
#700, -300

# %%
from shapely.geometry import Point, Polygon
def Random_Points_in_Polygon(polygon, number):
    points = []
    minx, miny, maxx, maxy = polygon.bounds
    while len(points) < number:
        pnt = Point(np.random.uniform(minx, maxx), np.random.uniform(miny, maxy))
        if polygon.contains(pnt):
            points.append(pnt)
    return points

x = np.arange(0, 1000, 0.1, dtype=np.double)
y1=-x
y2=-x+200
y3=-x+400
plt.plot(x, y1, 'gray')
plt.plot(x, y2, 'k--')
plt.plot(x, y3, 'gray')

px=200
plt.plot(px, -px, 'C1.', markersize=5)
px=300
plt.plot(px, -px+400, 'C0.', markersize=5)
px=700
plt.plot(px, -px+400, 'C0.', markersize=5)


u=40
polygon = Polygon([[min(x+u), max(y3+u)],[max(x-u), max(y3+u)],[max(x-u), min(y3+u)],[min(x+u), max(y3+u)]])
points = Random_Points_in_Polygon(polygon, 70)

xs = [point.x for point in points]
ys = [point.y for point in points]

plt.plot(xs, ys, '.', label='Class 1')



polygon2 = Polygon([[min(x+u), max(y1-u)],[min(x+u), min(y1-u)],[max(x-u), min(y1-u)],[min(x+u), max(y1-u)]])
points2 = Random_Points_in_Polygon(polygon2, 70)
xs2 = [point2.x for point2 in points2]
ys2 = [point2.y for point2 in points2]

plt.plot(xs2, ys2, '.', label='Class 2')
plt.text(120, 0, 'Margin', fontsize = 10, bbox = dict(facecolor = 'white', alpha = 0.9))
plt.text(600, 100, 'Support Vectors', fontsize = 10, bbox = dict(facecolor = 'white', alpha = 0.9))
plt.text(680, -600, 'Decision\nBoundary', fontsize = 10, bbox = dict(facecolor = 'white', alpha = 0.9))


pu=175
import matplotlib.patches as patches
style = "Simple, tail_width=0.5, head_width=4, head_length=8"
kw = dict(arrowstyle=style, color="k")
a1 = patches.FancyArrowPatch((pu, -pu+200), (120, -130), **kw)
plt.gca().add_patch(a1)
a2 = patches.FancyArrowPatch((pu, -pu+200), (220, 190), **kw)
plt.gca().add_patch(a2)


px=200
a3 = patches.FancyArrowPatch((700, 120), (px, -px), **kw)
plt.gca().add_patch(a3)
px=300
a4 = patches.FancyArrowPatch((700, 120), (px, -px+400), **kw)
plt.gca().add_patch(a4)
px=700
a5 = patches.FancyArrowPatch((700, 120), (px, -px+400), **kw)
plt.gca().add_patch(a5)

#plt.axis('off')
plt.legend(loc='upper right')
plt.savefig("SVM_Plots_4.2.pdf", format="pdf", bbox_inches="tight")

#200, -200
#200, 200
#700, -300
