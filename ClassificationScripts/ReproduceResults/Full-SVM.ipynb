# %% [markdown]
# ----
# # SVM classification using sklearn
# ----

# %%
# %load_ext autoreload
# %autoreload 2

from sklearn.metrics import confusion_matrix as skconfmatrix
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os

# Set correct working directory
if os.getcwd() != os.path.abspath("../Python"):
    os.chdir("../../Python")

# Import files from /Python directory
from confusion_matrix import confusion_matrix

# plt.rcParams.update({
#     "text.usetex": True,
#     "font.family": "cmr"
# })

# %%
# Use noisy data sets
noise = False

# Load data sets
trn_data = pd.read_csv(f"../TrainingData/neodata/soltani_all_{'' if noise else 'no'}noise_1200.csv")
vld_data = pd.read_csv(f"../ValidationData/neodata/soltani_all_{'' if noise else 'no'}noise_1200.csv")
tst_data = pd.read_csv(f"../TestData/neodata/soltani_all_{'' if noise else 'no'}noise_100.csv")

# Separate into data and targets
y_trn = trn_data.pop('target')
X_trn = trn_data

y_vld = vld_data.pop('target')
X_vld = vld_data

y_tst = tst_data.pop('target')
X_tst = tst_data

# %% [markdown]
# ## Standardize data

# %%
# Use standard scaler for scaling
from sklearn.preprocessing import StandardScaler
standardizer = StandardScaler()

# # Use PCA sphering/whitening for scaling
# from sklearn.decomposition import PCA
# standardizer = PCA(whiten=True)

X_trn = standardizer.fit_transform(X_trn)
X_vld = standardizer.transform(X_vld)
X_tst = standardizer.transform(X_tst)

# %% [markdown]
# ---
#
# # SVM fitting

# %%
# Training the SVM, on the 5 dimensional data
from sklearn import svm

clf = svm.SVC( C=1000, decision_function_shape="ovo", gamma=0.002 )
clf.fit(X_trn,y_trn)
# Out:
# SVC(C=1000, decision_function_shape='ovo', gamma=0.002)

# %% [markdown]
# # Classifying training data

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\laula\\OneDrive\\Documents\\GitHub\\p7-ml-refrigeration-fault-detection\\Python'

# %%
# Make predictions for the training set
y_hat_trn = clf.predict(X_trn)

#plot the confusion matrix
conf_matrix_trn = skconfmatrix(y_trn,y_hat_trn)
confusion_matrix(conf_matrix_trn, figsize = (10,10),title='SVM on training set',save_fig_name = "Full_SVM_training.pdf")
# Out:
# (<Figure size 1000x1000 with 1 Axes>,
#  <AxesSubplot:title={'center':'SVM on training set : Accuracy 89.79%'}, xlabel='Predicted class', ylabel='True class'>)

# %% [markdown]
# # Classifying validation data

# %%
# Make predictions for the training set
y_hat_vld = clf.predict(X_vld)

#plot the confusion matrix
conf_matrix_vld = skconfmatrix(y_vld,y_hat_vld)
confusion_matrix(conf_matrix_vld, figsize = (10,10),title='SVM on validation set',save_fig_name = "Full_SVM_validation.pdf")
# Out:
# (<Figure size 1000x1000 with 1 Axes>,
#  <AxesSubplot:title={'center':'SVM on validation set : Accuracy 89.901%'}, xlabel='Predicted class', ylabel='True class'>)

# %% [markdown]
# # Classifying test data

# %%
# Make predictions for the training set
y_hat_tst = clf.predict(X_tst)

#plot the confusion matrix
conf_matrix_vld = skconfmatrix(y_tst,y_hat_tst)
confusion_matrix(conf_matrix_vld, figsize = (10,10),title='SVM on test set',save_fig_name = "Full_SVM_test.pdf")
# Out:
# (<Figure size 1000x1000 with 1 Axes>,
#  <AxesSubplot:title={'center':'SVM on test set : Accuracy 85.714%'}, xlabel='Predicted class', ylabel='True class'>)
